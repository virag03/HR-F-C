# %%
import pandas as pd
dk = pd.read_csv('/content/IBM-HR-Analytics-Employee-Attrition-and-Performance.csv')

# %%
dk.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dk.shape
# Out:
# (1470, 35)

# %%
dk.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
dk.isna()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
dk.notnull()
# Out:
#        Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     True       True            True       True        True
# 1     True       True            True       True        True
# 2     True       True            True       True        True
# 3     True       True            True       True        True
# 4     True       True            True       True        True
# ...    ...        ...             ...        ...         ...
# 1465  True       True            True       True        True
# 1466  True       True            True       True        True
# 1467  True       True            True       True        True
# 1468  True       True            True       True        True
# 1469  True       True            True       True        True
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                 True       True            True           True
# 1                 True       True            True           True
# ...

# %%
dk.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
dk.describe(include="all")
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
dk.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
categorical_columns= dk.select_dtypes(include=['object','category']).columns
print(categorical_columns)
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
categorical_colums = dk.select_dtypes(include='object').columns
print(categorical_columns)
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
for col in categorical_columns:
  print(f"{col} - Unique values: {dk[col].unique()}")
  print(dk[col].value_counts(),"\n")
# Out:
# Attrition - Unique values: ['Yes' 'No']
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
# BusinessTravel - Unique values: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
# Department - Unique values: ['Sales' 'Research & Development' 'Human Resources']
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
# EducationField - Unique values: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
# Gender - Unique values: ['Female' 'Male']
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
# ...

# %%
import matplotlib as mp
import seaborn as sb
import matplotlib.pyplot as plt
bar_plot = dk['Attrition'].value_counts().plot(kind='bar',color=['red','blue'])
plt.title('Attrition count')
plt.xlabel('Attrition')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.show()

# %%
#SVM Model-1
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder

data = pd.read_csv('/content/IBM-HR-Analytics-Employee-Attrition-and-Performance.csv')

data['Attrition'] = LabelEncoder().fit_transform(data['Attrition'])
X = data.drop(columns=['Attrition'])
y = data['Attrition']

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.select_dtypes(include=['float64', 'int64']))


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)


model = SVC(kernel='linear')
model.fit(X_train, y_train)


predictions = model.predict(X_test)


accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.8673469387755102
# Confusion Matrix:
#  [[255   0]
#  [ 39   0]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       255
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.87       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.75      0.87      0.81       294
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
data['Attrition']=LabelEncoder().fit_transform(data['Attrition'])
x = data.drop(columns=['Attrition'])
y = data['Attrition']
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x.select_dtypes(include=['float64','int64']))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(data['Attrition'].value_counts())
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
model = SVC(kernel='linear', class_weight='balanced')  # Automatically adjusts weights based on class distribution

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[255   0]
#  [ 39   0]]

# %%
print(classification_report(y_test, predictions, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       255
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.87       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.75      0.87      0.81       294

# %%
from sklearn.svm import SVC

model = SVC(kernel='linear')
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
predictions = model.predict(X_test)

# %%
#SVM Model-2
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pandas as pd

data = pd.read_csv('/content/IBM-HR-Analytics-Employee-Attri  tion-and-Performance.csv')

data['Attrition'] = LabelEncoder().fit_transform(data['Attrition'])
X = data.drop(columns=['Attrition'])
y = data['Attrition']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.select_dtypes(include=['float64', 'int64']))

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Training SVM model with class weights
model = SVC(kernel='linear', class_weight='balanced')
model.fit(X_train, y_train)

# Make predictions
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions, zero_division=0))
# Out:
# Accuracy: 0.6768707482993197
# Confusion Matrix:
#  [[172  83]
#  [ 12  27]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78       255
#            1       0.25      0.69      0.36        39
#
#     accuracy                           0.68       294
#    macro avg       0.59      0.68      0.57       294
# weighted avg       0.84      0.68      0.73       294
